# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/jeoneunceong'

# %%
df = pd.read_csv('./traditional-liquor-RS/Naver_liquor_Wiki/naver_wiki_product_price_ver5.csv')
df
# Out:
#      Unnamed: 0  index            제품명   향기   단맛   신맛  청량감  바디감  목넘김   담백  ...  \
# 0             0      0  1000억막걸리프리바이오  NaN  3.0  4.0  3.0    3  NaN  NaN  ...
# 1             1      1    1000억유산균막걸리  NaN  3.0  5.0  5.0    3  NaN  NaN  ...
# 2             2      2  1932새싹땅콩햅쌀막걸리  NaN  2.0  2.0  3.0    5  NaN  NaN  ...
# 3             3      3  1932새싹땅콩흑미막걸리  NaN  3.0  1.0  1.0    4  NaN  NaN  ...
# 4             4      4           33JU  4.0  3.0  NaN  NaN    1  1.0  NaN  ...
# ..          ...    ...            ...  ...  ...  ...  ...  ...  ...  ...  ...
# 528         528    528         회곡생동동주  NaN  3.0  2.0  3.0    3  NaN  NaN  ...
# 529         529    529         회곡생막걸리  NaN  2.0  2.0  2.0    4  NaN  NaN  ...
# 530         530    530            흑돈주  2.0  NaN  NaN  NaN    2  3.0  NaN  ...
# 531         531    531       희양산막걸리15  NaN  3.0  4.0  1.0    5  NaN  NaN  ...
# 532         532    532        희양산막걸리9  NaN  2.0  3.0  2.0    3  NaN  3.0  ...
#
# ...

# %%
df2 = pd.read_csv('./traditional-liquor-RS/cbf_database.csv')
df2
# Out:
#      Unnamed: 0  index            제품명                         keyword
# 0             0      0  1000억막걸리프리바이오      단맛 신맛 청량감 바디감     탁주 쌀 밀
# 1             1      1    1000억유산균막걸리   단맛 신맛 청량감 바디감     탁주 쌀 밀  저도수
# 2             2      2  1932새싹땅콩햅쌀막걸리           청량감 바디감     탁주 쌀 땅콩
# 3             3      3  1932새싹땅콩흑미막걸리          단맛   바디감     탁주 쌀 땅콩
# 4             4      4           33JU          향기 단맛        증류주 꿀 삼
# ..          ...    ...            ...                             ...
# 528         528    528         회곡생동동주          단맛  청량감 바디감     탁주 쌀
# 529         529    529         회곡생막걸리                  바디감     탁주 쌀
# 530         530    530            흑돈주                   목넘김    기타주류
# 531         531    531       희양산막걸리15       단맛 신맛  바디감     탁주 쌀  무감미료
# 532         532    532        희양산막걸리9        신맛  바디감  담백   탁주 쌀  무감미료
#
# [533 rows x 4 columns]

# %%
df2['keyword']
# Out:
# 0          단맛 신맛 청량감 바디감     탁주 쌀 밀
# 1       단맛 신맛 청량감 바디감     탁주 쌀 밀  저도수
# 2               청량감 바디감     탁주 쌀 땅콩
# 3              단맛   바디감     탁주 쌀 땅콩
# 4              향기 단맛        증류주 꿀 삼
#                     ...
# 528            단맛  청량감 바디감     탁주 쌀
# 529                    바디감     탁주 쌀
# 530                     목넘김    기타주류
# 531         단맛 신맛  바디감     탁주 쌀  무감미료
# 532          신맛  바디감  담백   탁주 쌀  무감미료
# Name: keyword, Length: 533, dtype: object

# %%
df['keyword'] = df2['keyword']

# %%
df
# Out:
#      Unnamed: 0  index            제품명   향기   단맛   신맛  청량감  바디감  목넘김   담백  ...  \
# 0             0      0  1000억막걸리프리바이오  NaN  3.0  4.0  3.0    3  NaN  NaN  ...
# 1             1      1    1000억유산균막걸리  NaN  3.0  5.0  5.0    3  NaN  NaN  ...
# 2             2      2  1932새싹땅콩햅쌀막걸리  NaN  2.0  2.0  3.0    5  NaN  NaN  ...
# 3             3      3  1932새싹땅콩흑미막걸리  NaN  3.0  1.0  1.0    4  NaN  NaN  ...
# 4             4      4           33JU  4.0  3.0  NaN  NaN    1  1.0  NaN  ...
# ..          ...    ...            ...  ...  ...  ...  ...  ...  ...  ...  ...
# 528         528    528         회곡생동동주  NaN  3.0  2.0  3.0    3  NaN  NaN  ...
# 529         529    529         회곡생막걸리  NaN  2.0  2.0  2.0    4  NaN  NaN  ...
# 530         530    530            흑돈주  2.0  NaN  NaN  NaN    2  3.0  NaN  ...
# 531         531    531       희양산막걸리15  NaN  3.0  4.0  1.0    5  NaN  NaN  ...
# 532         532    532        희양산막걸리9  NaN  2.0  3.0  2.0    3  NaN  3.0  ...
#
# ...

# %%
df.drop(columns = ['Unnamed: 0','목넘김', '담백', '탄닌감', '향기', '원재료키워드', '키워드(thesool)'], axis = 1, inplace = True)

# %%
df = df[['index', '제품명', '단맛', '신맛', '청량감', '바디감', '도수%', '탄산', '주종', 'keyword', '용량', '가격', '제조사', '원재료', '어울리는음식(thesool)']]

# %%
df.drop(columns = ['어울리는음식(thesool)'], axis = 1, inplace = True)
df
# Out:
# /var/folders/nl/n0qszn8x2xnfmwlkhfgf8pzc0000gn/T/ipykernel_7194/3591749136.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns = ['어울리는음식(thesool)'], axis = 1, inplace = True)
#      index            제품명   단맛   신맛  청량감  바디감 도수%   탄산    주종  \
# 0        0  1000억막걸리프리바이오  3.0  4.0  3.0    3   5  NaN    탁주
# 1        1    1000억유산균막걸리  3.0  5.0  5.0    3   5  NaN    탁주
# 2        2  1932새싹땅콩햅쌀막걸리  2.0  2.0  3.0    5   6  NaN    탁주
# 3        3  1932새싹땅콩흑미막걸리  3.0  1.0  1.0    4   6  NaN    탁주
# 4        4           33JU  3.0  NaN  NaN    1  18  NaN   증류주
# ..     ...            ...  ...  ...  ...  ...  ..  ...   ...
# 528    528         회곡생동동주  3.0  2.0  3.0    3   7  NaN    탁주
# 529    529         회곡생막걸리  2.0  2.0  2.0    4   6  NaN    탁주
# ...

# %%
df['탄산'] = df['탄산'].fillna(0)
# Out:
# /var/folders/nl/n0qszn8x2xnfmwlkhfgf8pzc0000gn/T/ipykernel_7194/1748409350.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['탄산'] = df['탄산'].fillna(0)

# %%
df.to_csv('traditional_liquoar_df_final.csv')
