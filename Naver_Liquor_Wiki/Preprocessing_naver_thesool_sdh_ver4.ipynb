# %%
import pandas as pd
import numpy as np

# %%
df_ver3 = pd.read_csv('naver_wiki_product_ver3.csv')
df_ver3.drop(columns = ['Unnamed: 0'], axis = 1, inplace = True)
df_ver3.rename(columns = {'도수':'도수%'}, inplace = True)
df_ver3.drop(columns = ['제품명','향기','단맛','신맛','청량감','바디감','목넘김','균형감'], axis = 1, inplace = True)

# %%
df_rate = pd.read_csv('rate_pretty.csv')
df_rate
# Out:
#      index            제품명   향기   단맛   신맛  청량감  바디감  목넘김  균형감   담백  매운맛  씁쓸  \
# 0        0  1000억막걸리프리바이오  NaN  3.0  4.0  3.0  3.0  NaN  NaN  NaN  NaN NaN
# 1        1    1000억유산균막걸리  NaN  3.0  5.0  5.0  3.0  NaN  NaN  NaN  NaN NaN
# 2        2  1932새싹땅콩햅쌀막걸리  NaN  2.0  2.0  3.0  5.0  NaN  NaN  NaN  NaN NaN
# 3        3  1932새싹땅콩흑미막걸리  NaN  3.0  1.0  1.0  4.0  NaN  NaN  NaN  NaN NaN
# 4        4           33JU  4.0  3.0  NaN  NaN  1.0  1.0  NaN  NaN  NaN NaN
# ..     ...            ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ..
# 528    528         회곡생동동주  NaN  3.0  2.0  3.0  3.0  NaN  NaN  NaN  NaN NaN
# 529    529         회곡생막걸리  NaN  2.0  2.0  2.0  4.0  NaN  NaN  NaN  NaN NaN
# 530    530            흑돈주  2.0  NaN  NaN  NaN  2.0  3.0  NaN  NaN  NaN NaN
# 531    531       희양산막걸리15  NaN  3.0  4.0  1.0  5.0  NaN  NaN  NaN  NaN NaN
# 532    532        희양산막걸리9  NaN  2.0  3.0  2.0  3.0  NaN  NaN  3.0  NaN NaN
#
#      탄닌감   탄산
# 0    NaN  NaN
# 1    NaN  NaN
# 2    NaN  NaN
# ...

# %%
df_ver4 = pd.merge(df_rate, df_ver3, on='index')
df_ver4
# Out:
#      index            제품명   향기   단맛   신맛  청량감  바디감  목넘김  균형감   담백  ...   탄산  \
# 0        0  1000억막걸리프리바이오  NaN  3.0  4.0  3.0  3.0  NaN  NaN  NaN  ...  NaN
# 1        1    1000억유산균막걸리  NaN  3.0  5.0  5.0  3.0  NaN  NaN  NaN  ...  NaN
# 2        2  1932새싹땅콩햅쌀막걸리  NaN  2.0  2.0  3.0  5.0  NaN  NaN  NaN  ...  NaN
# 3        3  1932새싹땅콩흑미막걸리  NaN  3.0  1.0  1.0  4.0  NaN  NaN  NaN  ...  NaN
# 4        4           33JU  4.0  3.0  NaN  NaN  1.0  1.0  NaN  NaN  ...  NaN
# ..     ...            ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 528    528         회곡생동동주  NaN  3.0  2.0  3.0  3.0  NaN  NaN  NaN  ...  NaN
# 529    529         회곡생막걸리  NaN  2.0  2.0  2.0  4.0  NaN  NaN  NaN  ...  NaN
# 530    530            흑돈주  2.0  NaN  NaN  NaN  2.0  3.0  NaN  NaN  ...  NaN
# 531    531       희양산막걸리15  NaN  3.0  4.0  1.0  5.0  NaN  NaN  NaN  ...  NaN
# 532    532        희양산막걸리9  NaN  2.0  3.0  2.0  3.0  NaN  NaN  3.0  ...  0.0
#
# ...

# %%
df_ver4.info()
# 살릴 것 단맛, 신맛, 청량감, 바디감, 탄산(1010, thesool키워드에있는것 추가), 도수%, 
# 균형감, 씁쓸, 매운맛 버림 -> ver4 희지
# 담백(3~), 탄닌감(2~), 향기(3~)->키워드화 시은님 (리뷰pretty 올린 후에)
# 가격 null값 검색해서 채우고 용량 변경 -> 은정님
# 키워드컬럼 : [ 담백, 탄닌감, 향기, 원재료키워드, 키워드(thesool) ]
# 현재 이 상태로 모델링 작업해보고 음식은 나중에 고민.
# 술담화리뷰, 우리술상회 리뷰 제품명(index) 맞추고 한개로 만들기 [컬럼 - 제품명(index), 평점, 고객, 코멘트(리뷰글)] #희지
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 533 entries, 0 to 532
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            533 non-null    int64
#  1   제품명              533 non-null    object
#  2   향기               124 non-null    float64
#  3   단맛               463 non-null    float64
#  4   신맛               408 non-null    float64
#  5   청량감              387 non-null    float64
#  6   바디감              533 non-null    float64
#  7   목넘김              96 non-null     float64
#  8   균형감              8 non-null      float64
#  9   담백               71 non-null     float64
#  10  매운맛              44 non-null     float64
#  11  씁쓸               34 non-null     float64
#  12  탄닌감              24 non-null     float64
#  13  탄산               60 non-null     float64
#  14  주종               533 non-null    object
#  15  도수%              533 non-null    object
# ...

# %%
df_ver4.drop(columns = ['균형감','씁쓸','매운맛'], axis = 1, inplace = True)
df_ver4
# Out:
#      index            제품명   향기   단맛   신맛  청량감  바디감  목넘김   담백  탄닌감   탄산    주종  \
# 0        0  1000억막걸리프리바이오  NaN  3.0  4.0  3.0  3.0  NaN  NaN  NaN  NaN    탁주
# 1        1    1000억유산균막걸리  NaN  3.0  5.0  5.0  3.0  NaN  NaN  NaN  NaN    탁주
# 2        2  1932새싹땅콩햅쌀막걸리  NaN  2.0  2.0  3.0  5.0  NaN  NaN  NaN  NaN    탁주
# 3        3  1932새싹땅콩흑미막걸리  NaN  3.0  1.0  1.0  4.0  NaN  NaN  NaN  NaN    탁주
# 4        4           33JU  4.0  3.0  NaN  NaN  1.0  1.0  NaN  NaN  NaN   증류주
# ..     ...            ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 528    528         회곡생동동주  NaN  3.0  2.0  3.0  3.0  NaN  NaN  NaN  NaN    탁주
# 529    529         회곡생막걸리  NaN  2.0  2.0  2.0  4.0  NaN  NaN  NaN  NaN    탁주
# 530    530            흑돈주  2.0  NaN  NaN  NaN  2.0  3.0  NaN  NaN  NaN  기타주류
# 531    531       희양산막걸리15  NaN  3.0  4.0  1.0  5.0  NaN  NaN  NaN  NaN    탁주
# 532    532        희양산막걸리9  NaN  2.0  3.0  2.0  3.0  NaN  3.0  NaN  0.0    탁주
#
# ...

# %%
df_ver4.to_csv('naver_wiki_product_ver4.csv')
