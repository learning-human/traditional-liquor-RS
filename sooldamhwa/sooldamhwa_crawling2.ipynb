# %% [markdown]
# # 술담화 크롤링 연습

# %% [markdown]
# ### package import

# %%
# 필요패키지 import
import time
import json
import urllib
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import csv

# %% [markdown]
# ### crawling sample : 술담화 상세 페이지 - food_wrapper

# %%
# url정의
url = "https://www.sooldamhwa.com/damhwaMarket/detail/100"
# requsts로 url에 정보요청
resp = requests.get(url)
# 정보를 html 변환 (보기 쉽게)
html = BeautifulSoup(resp.text,"html.parser")
# html 내에서 우리가 보고 싶은 정보만 선별 (이미지)

# %%
html

# %% [markdown]
# food_wrapper만 불러와서 list에 저장, df 만들기

# %%
# 중간중간 비어있는 페이지, 술 단일 품목이 아닌 세트 구성 상품이 많기 때문에 이를 제외하고 돌아가도록 if문 설계



foodwrapper_list = []

for page in range(1000, 1400) :
    #time sleep   
    seed = np.random.randint(100)
    np.random.seed(seed)
    a = np.random.randint(5) 
    time.sleep(a)
    # url 설정
    url = f"https://www.sooldamhwa.com/damhwaMarket/detail/{page}"
        # requests로 데이터 요청하기
    resp = requests.get(url)
    html = BeautifulSoup(resp.text, "html.parser")

    if resp.status_code == requests.codes.NOT_FOUND:
        print(f"{page}페이지를 건너뜁니다.")

    elif not html.select("div.food-wrapper") :
        print(f"{page}페이지는 술 제품이 아니네요!")

    elif resp.status_code == requests.codes.ok:
        print(f"{page}페이지 크롤링 중입니다.")
        # html로 변환
        html = BeautifulSoup(resp.text, "html.parser")
        # page 숫자 추가
        foodwrapper_list.append(f"{page}")
        # 술 이름 추가
        liquorname = html.select("div.productName")[0].text
        foodwrapper_list.append(liquorname)
        # 데이터 선별
        for food in html.select("div.food-wrapper")[:5] :
            foodwrapper_list.append(food.text)

         
print("크롤링 완료!")
# Out:
# 1000페이지는 술 제품이 아니네요!
# 1001페이지를 건너뜁니다.
# 1002페이지를 건너뜁니다.
# 1003페이지를 건너뜁니다.
# 1004페이지를 건너뜁니다.
# 1005페이지를 건너뜁니다.
# 1006페이지는 술 제품이 아니네요!
# 1007페이지 크롤링 중입니다.
# 1008페이지 크롤링 중입니다.
# 1009페이지를 건너뜁니다.
# 1010페이지를 건너뜁니다.
# 1011페이지를 건너뜁니다.
# 1012페이지는 술 제품이 아니네요!
# 1013페이지 크롤링 중입니다.
# 1014페이지 크롤링 중입니다.
# 1015페이지 크롤링 중입니다.
# 1016페이지 크롤링 중입니다.
# 1017페이지를 건너뜁니다.
# 1018페이지 크롤링 중입니다.
# 1019페이지 크롤링 중입니다.
# 1020페이지 크롤링 중입니다.
# 1021페이지 크롤링 중입니다.
# 1022페이지는 술 제품이 아니네요!
# 1023페이지는 술 제품이 아니네요!
# 1024페이지를 건너뜁니다.
# 1025페이지는 술 제품이 아니네요!
# 1026페이지는 술 제품이 아니네요!
# 1027페이지는 술 제품이 아니네요!
# 1028페이지는 술 제품이 아니네요!
# 1029페이지는 술 제품이 아니네요!
# 1030페이지는 술 제품이 아니네요!
# 1031페이지는 술 제품이 아니네요!
# 1032페이지는 술 제품이 아니네요!
# 1033페이지를 건너뜁니다.
# 1034페이지를 건너뜁니다.
# 1035페이지는 술 제품이 아니네요!
# 1036페이지는 술 제품이 아니네요!
# 1037페이지 크롤링 중입니다.
# 1038페이지를 건너뜁니다.
# 1039페이지를 건너뜁니다.
# 1040페이지를 건너뜁니다.
# 1041페이지를 건너뜁니다.
# 1042페이지를 건너뜁니다.
# 1043페이지 크롤링 중입니다.
# 1044페이지는 술 제품이 아니네요!
# 1045페이지는 술 제품이 아니네요!
# 1046페이지를 건너뜁니다.
# 1047페이지는 술 제품이 아니네요!
# 1048페이지는 술 제품이 아니네요!
# 1049페이지 크롤링 중입니다.
# 1050페이지 크롤링 중입니다.
# 1051페이지 크롤링 중입니다.
# 1052페이지 크롤링 중입니다.
# 1053페이지를 건너뜁니다.
# 1054페이지 크롤링 중입니다.
# 1055페이지 크롤링 중입니다.
# 1056페이지는 술 제품이 아니네요!
# 1057페이지 크롤링 중입니다.
# 1058페이지 크롤링 중입니다.
# 1059페이지 크롤링 중입니다.
# 1060페이지 크롤링 중입니다.
# 1061페이지 크롤링 중입니다.
# 1062페이지 크롤링 중입니다.
# 1063페이지 크롤링 중입니다.
# 1064페이지 크롤링 중입니다.
# 1065페이지 크롤링 중입니다.
# 1066페이지는 술 제품이 아니네요!
# 1067페이지는 술 제품이 아니네요!
# 1068페이지는 술 제품이 아니네요!
# 1069페이지는 술 제품이 아니네요!
# 1070페이지 크롤링 중입니다.
# 1071페이지 크롤링 중입니다.
# 1072페이지 크롤링 중입니다.
# 1073페이지는 술 제품이 아니네요!
# 1074페이지 크롤링 중입니다.
# 1075페이지는 술 제품이 아니네요!
# 1076페이지는 술 제품이 아니네요!
# 1077페이지는 술 제품이 아니네요!
# 1078페이지는 술 제품이 아니네요!
# 1079페이지는 술 제품이 아니네요!
# 1080페이지를 건너뜁니다.
# 1081페이지를 건너뜁니다.
# 1082페이지는 술 제품이 아니네요!
# 1083페이지는 술 제품이 아니네요!
# 1084페이지는 술 제품이 아니네요!
# 1085페이지 크롤링 중입니다.
# 1086페이지는 술 제품이 아니네요!
# 1087페이지는 술 제품이 아니네요!
# 1088페이지를 건너뜁니다.
# 1089페이지는 술 제품이 아니네요!
# 1090페이지는 술 제품이 아니네요!
# 1091페이지는 술 제품이 아니네요!
# 1092페이지 크롤링 중입니다.
# 1093페이지 크롤링 중입니다.
# 1094페이지 크롤링 중입니다.
# 1095페이지 크롤링 중입니다.
# 1096페이지 크롤링 중입니다.
# 1097페이지를 건너뜁니다.
# 1098페이지 크롤링 중입니다.
# 1099페이지 크롤링 중입니다.
# 1100페이지 크롤링 중입니다.
# 1101페이지 크롤링 중입니다.
# 1102페이지 크롤링 중입니다.
# 1103페이지는 술 제품이 아니네요!
# 1104페이지는 술 제품이 아니네요!
# 1105페이지 크롤링 중입니다.
# 1106페이지 크롤링 중입니다.
# 1107페이지 크롤링 중입니다.
# 1108페이지는 술 제품이 아니네요!
# 1109페이지 크롤링 중입니다.
# 1110페이지 크롤링 중입니다.
# 1111페이지 크롤링 중입니다.
# 1112페이지 크롤링 중입니다.
# 1113페이지 크롤링 중입니다.
# 1114페이지는 술 제품이 아니네요!
# 1115페이지 크롤링 중입니다.
# 1116페이지 크롤링 중입니다.
# 1117페이지는 술 제품이 아니네요!
# 1118페이지 크롤링 중입니다.
# 1119페이지 크롤링 중입니다.
# 1120페이지는 술 제품이 아니네요!
# 1121페이지는 술 제품이 아니네요!
# 1122페이지 크롤링 중입니다.
# 1123페이지 크롤링 중입니다.
# 1124페이지 크롤링 중입니다.
# 1125페이지 크롤링 중입니다.
# 1126페이지 크롤링 중입니다.
# 1127페이지는 술 제품이 아니네요!
# 1128페이지 크롤링 중입니다.
# 1129페이지 크롤링 중입니다.
# 1130페이지는 술 제품이 아니네요!
# 1131페이지는 술 제품이 아니네요!
# 1132페이지 크롤링 중입니다.
# 1133페이지는 술 제품이 아니네요!
# 1134페이지 크롤링 중입니다.
# 1135페이지는 술 제품이 아니네요!
# 1136페이지 크롤링 중입니다.
# 1137페이지 크롤링 중입니다.
# 1138페이지 크롤링 중입니다.
# 1139페이지 크롤링 중입니다.
# 1140페이지 크롤링 중입니다.
# 1141페이지는 술 제품이 아니네요!
# 1142페이지 크롤링 중입니다.
# 1143페이지는 술 제품이 아니네요!
# 1144페이지를 건너뜁니다.
# 1145페이지를 건너뜁니다.
# 1146페이지는 술 제품이 아니네요!
# 1147페이지 크롤링 중입니다.
# 1148페이지는 술 제품이 아니네요!
# 1149페이지 크롤링 중입니다.
# 1150페이지 크롤링 중입니다.
# 1151페이지는 술 제품이 아니네요!
# 1152페이지는 술 제품이 아니네요!
# 1153페이지는 술 제품이 아니네요!
# 1154페이지 크롤링 중입니다.
# 1155페이지는 술 제품이 아니네요!
# 1156페이지 크롤링 중입니다.
# 1157페이지 크롤링 중입니다.
# 1158페이지 크롤링 중입니다.
# 1159페이지는 술 제품이 아니네요!
# 1160페이지를 건너뜁니다.
# 1161페이지를 건너뜁니다.
# 1162페이지는 술 제품이 아니네요!
# 1163페이지는 술 제품이 아니네요!
# 1164페이지 크롤링 중입니다.
# 1165페이지 크롤링 중입니다.
# 1166페이지 크롤링 중입니다.
# 1167페이지 크롤링 중입니다.
# 1168페이지는 술 제품이 아니네요!
# 1169페이지 크롤링 중입니다.
# 1170페이지 크롤링 중입니다.
# 1171페이지 크롤링 중입니다.
# 1172페이지는 술 제품이 아니네요!
# 1173페이지는 술 제품이 아니네요!
# 1174페이지는 술 제품이 아니네요!
# 1175페이지는 술 제품이 아니네요!
# 1176페이지는 술 제품이 아니네요!
# 1177페이지 크롤링 중입니다.
# 1178페이지 크롤링 중입니다.
# 1179페이지는 술 제품이 아니네요!
# 1180페이지는 술 제품이 아니네요!
# 1181페이지는 술 제품이 아니네요!
# 1182페이지는 술 제품이 아니네요!
# 1183페이지는 술 제품이 아니네요!
# 1184페이지는 술 제품이 아니네요!
# 1185페이지는 술 제품이 아니네요!
# 1186페이지는 술 제품이 아니네요!
# 1187페이지 크롤링 중입니다.
# 1188페이지 크롤링 중입니다.
# 1189페이지 크롤링 중입니다.
# 1190페이지 크롤링 중입니다.
# 1191페이지 크롤링 중입니다.
# 1192페이지는 술 제품이 아니네요!
# 1193페이지는 술 제품이 아니네요!
# 1194페이지는 술 제품이 아니네요!
# 1195페이지는 술 제품이 아니네요!
# 1196페이지 크롤링 중입니다.
# 1197페이지는 술 제품이 아니네요!
# 1198페이지 크롤링 중입니다.
# 1199페이지 크롤링 중입니다.
# 1200페이지는 술 제품이 아니네요!
# 1201페이지 크롤링 중입니다.
# 1202페이지 크롤링 중입니다.
# 1203페이지 크롤링 중입니다.
# 1204페이지는 술 제품이 아니네요!
# 1205페이지 크롤링 중입니다.
# 1206페이지는 술 제품이 아니네요!
# 1207페이지 크롤링 중입니다.
# 1208페이지는 술 제품이 아니네요!
# 1209페이지는 술 제품이 아니네요!
# 1210페이지를 건너뜁니다.
# 1211페이지를 건너뜁니다.
# 1212페이지 크롤링 중입니다.
# 1213페이지는 술 제품이 아니네요!
# 1214페이지 크롤링 중입니다.
# 1215페이지는 술 제품이 아니네요!
# 1216페이지 크롤링 중입니다.
# 1217페이지 크롤링 중입니다.
# 1218페이지는 술 제품이 아니네요!
# 1219페이지 크롤링 중입니다.
# 1220페이지 크롤링 중입니다.
# 1221페이지 크롤링 중입니다.
# 1222페이지는 술 제품이 아니네요!
# 1223페이지 크롤링 중입니다.
# 1224페이지 크롤링 중입니다.
# 1225페이지 크롤링 중입니다.
# 1226페이지는 술 제품이 아니네요!
# 1227페이지 크롤링 중입니다.
# 1228페이지는 술 제품이 아니네요!
# 1229페이지는 술 제품이 아니네요!
# 1230페이지 크롤링 중입니다.
# 1231페이지 크롤링 중입니다.
# 1232페이지는 술 제품이 아니네요!
# 1233페이지는 술 제품이 아니네요!
# 1234페이지 크롤링 중입니다.
# 1235페이지 크롤링 중입니다.
# 1236페이지 크롤링 중입니다.
# 1237페이지 크롤링 중입니다.
# 1238페이지 크롤링 중입니다.
# 1239페이지 크롤링 중입니다.
# 1240페이지는 술 제품이 아니네요!
# 1241페이지 크롤링 중입니다.
# 1242페이지 크롤링 중입니다.
# 1243페이지는 술 제품이 아니네요!
# 1244페이지는 술 제품이 아니네요!
# 1245페이지는 술 제품이 아니네요!
# 1246페이지 크롤링 중입니다.
# 1247페이지 크롤링 중입니다.
# 1248페이지 크롤링 중입니다.
# 1249페이지 크롤링 중입니다.
# 1250페이지 크롤링 중입니다.
# 1251페이지 크롤링 중입니다.
# 1252페이지 크롤링 중입니다.
# 1253페이지 크롤링 중입니다.
# 1254페이지 크롤링 중입니다.
# 1255페이지 크롤링 중입니다.
# 1256페이지 크롤링 중입니다.
# 1257페이지 크롤링 중입니다.
# 1258페이지를 건너뜁니다.
# 1259페이지는 술 제품이 아니네요!
# 1260페이지 크롤링 중입니다.
# 1261페이지 크롤링 중입니다.
# 1262페이지 크롤링 중입니다.
# 1263페이지는 술 제품이 아니네요!
# 1264페이지 크롤링 중입니다.
# 1265페이지 크롤링 중입니다.
# 1266페이지는 술 제품이 아니네요!
# 1267페이지 크롤링 중입니다.
# 1268페이지 크롤링 중입니다.
# 1269페이지 크롤링 중입니다.
# 1270페이지는 술 제품이 아니네요!
# 1271페이지는 술 제품이 아니네요!
# 1272페이지 크롤링 중입니다.
# 1273페이지는 술 제품이 아니네요!
# 1274페이지 크롤링 중입니다.
# 1275페이지 크롤링 중입니다.
# 1276페이지는 술 제품이 아니네요!
# 1277페이지는 술 제품이 아니네요!
# 1278페이지 크롤링 중입니다.
# 1279페이지 크롤링 중입니다.
# 1280페이지 크롤링 중입니다.
# 1281페이지는 술 제품이 아니네요!
# 1282페이지를 건너뜁니다.
# 1283페이지는 술 제품이 아니네요!
# 1284페이지는 술 제품이 아니네요!
# 1285페이지는 술 제품이 아니네요!
# 1286페이지는 술 제품이 아니네요!
# 1287페이지 크롤링 중입니다.
# 1288페이지 크롤링 중입니다.
# 1289페이지는 술 제품이 아니네요!
# 1290페이지는 술 제품이 아니네요!
# 1291페이지는 술 제품이 아니네요!
# 1292페이지는 술 제품이 아니네요!
# 1293페이지는 술 제품이 아니네요!
# 1294페이지 크롤링 중입니다.
# 1295페이지 크롤링 중입니다.
# 1296페이지는 술 제품이 아니네요!
# 1297페이지는 술 제품이 아니네요!
# 1298페이지는 술 제품이 아니네요!
# 1299페이지는 술 제품이 아니네요!
# 1300페이지는 술 제품이 아니네요!
# 1301페이지는 술 제품이 아니네요!
# 1302페이지는 술 제품이 아니네요!
# 1303페이지 크롤링 중입니다.
# 1304페이지는 술 제품이 아니네요!
# 1305페이지는 술 제품이 아니네요!
# 1306페이지는 술 제품이 아니네요!
# 1307페이지는 술 제품이 아니네요!
# 1308페이지 크롤링 중입니다.
# 1309페이지 크롤링 중입니다.
# 1310페이지는 술 제품이 아니네요!
# 1311페이지는 술 제품이 아니네요!
# 1312페이지는 술 제품이 아니네요!
# 1313페이지는 술 제품이 아니네요!
# 1314페이지는 술 제품이 아니네요!
# 1315페이지는 술 제품이 아니네요!
# 1316페이지는 술 제품이 아니네요!
# 1317페이지는 술 제품이 아니네요!
# 1318페이지는 술 제품이 아니네요!
# 1319페이지는 술 제품이 아니네요!
# 1320페이지는 술 제품이 아니네요!
# 1321페이지 크롤링 중입니다.
# 1322페이지 크롤링 중입니다.
# 1323페이지는 술 제품이 아니네요!
# 1324페이지는 술 제품이 아니네요!
# 1325페이지는 술 제품이 아니네요!
# 1326페이지 크롤링 중입니다.
# 1327페이지 크롤링 중입니다.
# 1328페이지는 술 제품이 아니네요!
# 1329페이지는 술 제품이 아니네요!
# 1330페이지는 술 제품이 아니네요!
# 1331페이지는 술 제품이 아니네요!
# 1332페이지는 술 제품이 아니네요!
# 1333페이지는 술 제품이 아니네요!
# 1334페이지는 술 제품이 아니네요!
# 1335페이지는 술 제품이 아니네요!
# 1336페이지는 술 제품이 아니네요!
# 1337페이지는 술 제품이 아니네요!
# 1338페이지 크롤링 중입니다.
# 1339페이지를 건너뜁니다.
# 1340페이지는 술 제품이 아니네요!
# 1341페이지는 술 제품이 아니네요!
# 1342페이지는 술 제품이 아니네요!
# 1343페이지를 건너뜁니다.
# 1344페이지를 건너뜁니다.
# 1345페이지를 건너뜁니다.
# 1346페이지를 건너뜁니다.
# 1347페이지를 건너뜁니다.
# 1348페이지를 건너뜁니다.
# 1349페이지를 건너뜁니다.
# 1350페이지를 건너뜁니다.
# 1351페이지를 건너뜁니다.
# 1352페이지를 건너뜁니다.
# 1353페이지를 건너뜁니다.
# 1354페이지를 건너뜁니다.
# 1355페이지를 건너뜁니다.
# 1356페이지를 건너뜁니다.
# 1357페이지를 건너뜁니다.
# 1358페이지를 건너뜁니다.
# 1359페이지를 건너뜁니다.
# 1360페이지를 건너뜁니다.
# 1361페이지를 건너뜁니다.
# 1362페이지를 건너뜁니다.
# 1363페이지를 건너뜁니다.
# 1364페이지를 건너뜁니다.
# 1365페이지를 건너뜁니다.
# 1366페이지를 건너뜁니다.
# 1367페이지를 건너뜁니다.
# 1368페이지를 건너뜁니다.
# 1369페이지를 건너뜁니다.
# 1370페이지를 건너뜁니다.
# 1371페이지를 건너뜁니다.
# 1372페이지를 건너뜁니다.
# 1373페이지를 건너뜁니다.
# 1374페이지를 건너뜁니다.
# 1375페이지를 건너뜁니다.
# 1376페이지를 건너뜁니다.
# 1377페이지를 건너뜁니다.
# 1378페이지를 건너뜁니다.
# 1379페이지를 건너뜁니다.
# 1380페이지를 건너뜁니다.
# 1381페이지를 건너뜁니다.
# 1382페이지를 건너뜁니다.
# 1383페이지를 건너뜁니다.
# 1384페이지를 건너뜁니다.
# 1385페이지를 건너뜁니다.
# 1386페이지를 건너뜁니다.
# 1387페이지를 건너뜁니다.
# 1388페이지를 건너뜁니다.
# 1389페이지를 건너뜁니다.
# 1390페이지를 건너뜁니다.
# 1391페이지를 건너뜁니다.
# 1392페이지를 건너뜁니다.
# 1393페이지를 건너뜁니다.
# 1394페이지를 건너뜁니다.
# 1395페이지를 건너뜁니다.
# 1396페이지를 건너뜁니다.
# 1397페이지를 건너뜁니다.
# 1398페이지를 건너뜁니다.
# 1399페이지를 건너뜁니다.
# 크롤링 완료!

# %%
foodwrapper_list = np.array(foodwrapper_list).reshape(-1,5)
foodwrapper_list
# Out:
# array([['1007', '겨울소주 45%', '버섯 전골', '삼계탕', '갈비찜'],
#        ['1008', '진맥소주 53%', '보쌈', '장어구이', '안심 스테이크'],
#        ['1013', '이도 32%', '삼겹살', '곱창', '족발'],
#        ['1014', '이도 42%', '불고기', '닭갈비', '해물탕'],
#        ['1015', '감사 블루', '고등어구이', '육전', '대패 삼겹살'],
#        ['1016', '미르 40%', '밀푀유나베', '만두 전골', '도미회'],
#        ['1018', '미르 54%', '족발', '해물탕', '도미회'],
#        ['1019', '문경바람 백자 25%', '과일 샐러드', '리코타치즈', '견과류'],
#        ['1020', '고소리술 40%', '삼겹살', '곱창', '돼지고기 김치찜'],
#        ['1021', '문경바람 오크 25%', '육포', '베이컨', '견과류'],
#        ['1037', '오메기술 15%', '수육', '순대 볶음', '돼지국밥'],
#        ['1043', '만월 24%', '바지락 술찜', '참치회', '참소라'],
#        ['1049', '금설', '버섯 전골', '삼계탕', '농어회'],
#        ['1050', '한청', '비빔면', '유부초밥', '동치미막국수'],
#        ['1051', '궁중술 왕주', '바지락 술찜', '불고기', '찜닭'],
#        ['1052', '대대포 블루 [8병/12병]', '양념 치킨', '불닭볶음면', '떡볶이'],
#        ['1054', '만월 40%', '삼겹살', '방어회', '고등어 회'],
#        ['1055', '문배술 25%', '양꼬치', '간장 불고기', '삼치구이'],
#        ['1057', '용봉약주 오향주 X 2병', '보쌈', '오리 구이', '가래떡 구이'],
#        ['1058', '용봉백주 오향주 X 2병', '오뎅탕', '낙지 볶음', '두부김치'],
#        ['1059', '멜론서리 X 9병', '토마토샐러드', '과일', '하몽'],
#        ['1060', '시나브로 청수 화이트', '새우튀김', '굴', '크림소스 연어 스테이크'],
#        ['1061', '시나브로 에뚜왈 로제 스파클링 와인', '프로슈토', '올리브', '크림치즈'],
#        ['1062', '시나브로 캠벨 스위트', '오리 고기', '스테이크', '페퍼로니 피자'],
#        ['1063', '추사백 25%', '샤브샤브', '보쌈', '양꼬치'],
#        ['1064', '동백꽃, 제주', '육포', '크래커', '멜론 프로슈토'],
#        ['1065', '모리', '버섯 전골', '굴', '오징어 숙회'],
#        ['1070', '벗이랑 강황', '초코 케이크', '과일치즈', '크로플'],
#        ['1071', '벗이랑 조릿대', '초콜릿', '동치미막국수', '도넛'],
#        ['1072', '벗이랑 홍국', '육전', '고추장 삼겹살', '양념 장어구이'],
#        ['1074', '삼천갑자 동방주', '더덕구이', '한방백숙', '닭곰탕'],
#        ['1085', '밀담 52%', '양념갈비', '양꼬치', '칠리 새우'],
#        ['1092', '안동소주 일품 40% 골드', '고등어구이', '산적 꼬치', '삼겹살'],
#        ['1093', '백련 미스티 살균 막걸리', '순대 볶음', '감자전', '갈비찜'],
#        ['1094', '고도리 샤인머스캣 와인 (망고포도)', '바질 파스타', '토스트', '루꼴라피자'],
#        ['1095', '냥이탁주 5% fresh X 2병', '골뱅이 무침', '감자전', '브루스케타'],
#        ['1096', '냥이탁주 9% X 2병', '해물 파전', '양념 치킨', '간장 불고기'],
#        ['1098', '부안 해풍 오디주', '과일치즈', '토스트', '호두강정'],
#        ['1099', '삼양춘 탁주 라이트 X 3병', '피자', '갈비 구이', '로제 떡볶이'],
#        ['1100', '지란지교 약주', '간장 치킨', '굴국', '버섯 볶음'],
#        ['1101', '지란지교 탁주', '라자냐', '가지볶음', '버터 갈릭 새우'],
#        ['1102', '지란지교 무화과 탁주', '불족발', '곱창', '훈제오리 냉채'],
#        ['1105', '솔섬 17%', '닭볶음탕', '오돌뼈', '막창'],
#        ['1106', '솔섬 25%', '떡갈비', '양고기', '고등어 회'],
#        ['1107', '막시모', '곱창', '다크 초콜릿', '훈제오리 샐러드'],
#        ['1109', '무작 53%', '곱창전골', '참치회', '대구지리탕'],
#        ['1110', '무작 30%', '메밀 전병', '고추장 삼겹살', '해물 순두부'],
#        ['1111', '신애유자', '닭가슴살 샐러드', '양념 치킨', '페퍼로니 피자'],
#        ['1112', '두레앙 22% X 6병', '바지락 술찜', '순대', '불고기 샐러드'],
#        ['1113', '두레앙 일반증류주 35%', '육포', '샤브샤브', '안심 스테이크'],
#        ['1115', '여포의 꿈 레드와인 (스위트)', '과일치즈', '당근 케이크', '솔트 카라멜 아몬드'],
#        ['1116', '여포의 꿈 레드와인 (드라이)', '오리 고기', '안심 스테이크', '삼치구이'],
#        ['1118', '만강에 비친 달 X 2병', '오리 고기', '불고기', '찹스테이크'],
#        ['1119', '여포의 꿈 화이트와인', '떡갈비', '연어 스테이크', '치킨너겟'],
#        ['1122', '모월 인 41%', '닭 안심 스테이크', '숯불 돼지구이', '알탕'],
#        ['1123', '초선의 꿈 로제와인', '리코타치즈', '가리비 치즈 구이', '요거트'],
#        ['1124', '치키피치', '과일 샐러드', '페퍼로니 피자', '복숭아 타르트'],
#        ['1125', '동짓달 기나긴 밤', '닭갈비', '장어구이', '등심 스테이크'],
#        ['1126', '바람의 노래 X 2병', '짜장면', '간장 불고기', '오징어 튀김'],
#        ['1128', '모월 로 25%', '닭발', '삼겹살', '육회'],
#        ['1129', '양조학당 애', '마라샹궈', '양꼬치', '양장피'],
#        ['1132', '그랑꼬또 랑 로제와인', '과일치즈', '애플 파이', '꿀떡'],
#        ['1134', '그랑꼬또 청수 화이트와인', '게살 볶음밥', '봉골레 파스타', '굴 튀김'],
#        ['1136', '샤토미소 웨딩 자두와인', '연어 스테이크', '월남쌈', '오징어 튀김'],
#        ['1137', '샤토미소 로제와인 (스위트)', '과일치즈', '불고기', '로제 떡볶이'],
#        ['1138', '샤토미소 퀸 아이스와인', '치즈 케이크', '핑거푸드', '가래떡 구이'],
#        ['1139', '기다림 백미 약주', '데리야끼 치킨', '오징어 순대', '꼼장어'],
#        ['1140', '기다림 흑미 약주', '해물찜', '간장 불고기', '토스트'],
#        ['1142', '동래아들 [6병/12병]', '닭볶음탕', '아구찜', '떡볶이'],
#        ['1147', '보일러 틀어놨어 X 2병', '해물찜', '닭갈비', '꼼장어'],
#        ['1149', '샤토미소 랑 화이트와인 (스위트)', 'LA갈비', '깐쇼새우', '감귤 타르트'],
#        ['1150', '샤토미소 애플 와인', '수육', '월남쌈', '훈제오리 샐러드'],
#        ['1154', '아이엠더문 아이스버켓 특별 패키지 [아이엠더문 + 아이스버킷 + 얼음집게]', '카나페',
#         '연어샐러드', '치즈 케이크'],
#        ['1156', '샤토미소 영동', '방어회', '대구지리탕', '삼치구이'],
#        ['1157', '모든날에', '간장 게장', '고등어구이', '찜닭'],
#        ['1158', '양지백주', '닭볶음탕', '고추장 찌개', '콩나물 무침'],
#        ['1164', '하얀 까마귀 X 3병', '찜닭', '돈까스', '콘치즈'],
#        ['1165', '여유 40%', '육전', '방어회', '양갈비 구이'],
#        ['1166', '한주 25%', '바지락 술찜', '오뎅탕', '삼겹살'],
#        ['1167', '진도 아리랑 홍주 40%', '까르보나라', '밀푀유나베', '양갈비 구이'],
#        ['1169', '청비성', '궁중 떡볶이', '간장 치킨', '두부 조림'],
#        ['1170', '달홀진주 40%', '골뱅이 무침', '오일 파스타', '감바스'],
#        ['1171', '농태기 25%', '들깨수제비', '순대국', '돼지국밥'],
#        ['1177', '운암 1945', '소시지', '해물 파전', '생선회'],
#        ['1178', '우포', '양념 치킨', '간장 불고기', '고구마 맛탕'],
#        ['1187', '서설', '광어회', '어묵전골', '나가사키 짬뽕'],
#        ['1188', '아카시아 미드 Batch3', '고르곤졸라 피자', '떡꼬치', '허니버터 브레드'],
#        ['1189', '얼떨결에 퍼플 X 3병', '까르보나라', '맥앤치즈', '피자'],
#        ['1190', '용봉소주 25%', '대구지리탕', '어묵전골', '평양냉면'],
#        ['1191', '삭제', '오돌뼈', '피자', '불닭볶음면'],
#        ['1196', '장수 오미자주', '돼지갈비 찜', '간장 불고기', '치킨 샐러드'],
#        ['1198', '배금도가 수제 막걸리', '막창', '돼지껍데기', '통닭 구이'],
#        ['1199', '표문 막걸리 X 4병', '오돌뼈', '피자', '불닭볶음면'],
#        ['1201', '자연담은 복분자 막걸리 4병 세트', '전복 버터구이', '삼계탕', '장어구이'],
#        ['1202', '크라테 자두 와인', '과일치즈', '삼겹살', '소고기 등심구이'],
#        ['1203', '매화깊은밤', '차돌박이 숙주 볶음', '시저 샐러드', '백순대 볶음'],
#        ['1205', '청주신선주 약주 16%', '도토리묵 무침', '오징어 초무침', '냉채 족발'],
#        ['1207', '희양산막걸리 9% X 3병', '탕수육', '칠리 새우', '양념 치킨'],
#        ['1212', '보리수헤는밤', '돼지고기 김치찜', '로제 떡볶이', '고추장 찜닭'],
#        ['1214', '유채꽃, 제주', '리코타치즈', '문어 숙회', '버터 갈릭 새우'],
#        ['1216', '안동 국화주 32%', '조개찜', '대구지리탕', '연포탕'],
#        ['1217', '오메기술 13%', '치즈', '흑돼지 삼겹살', '생선회'],
#        ['1219', '백련 맑은 술', '떡갈비', '된장찌개', '누룽지탕'],
#        ['1220', '마실꾸지 [3병/6병/12병]', '도넛', '양갈비 구이', '훈제 삼겹살'],
#        ['1221', '분홍탁주 6% [3병/6병]', '샤브샤브', '육회', '연포탕'],
#        ['1223', '상록수 40%', '떡갈비', '빈대떡', '꿔바로우'],
#        ['1224', '허니문배', '월남쌈', '연어회', '훈제오리 냉채'],
#        ['1225', '마주', '버섯 전골', '쑥전', '미나리 삼겹살'],
#        ['1227', '나주 배 약주', '에그타르트', '치킨 샐러드', '육사시미'],
#        ['1230', '이상헌 탁주 14%', '수육', '부추전', '두부부침'],
#        ['1231', '오미로제 투게더', '바비큐 폭립', '소고기 등심구이', '로제 파스타'],
#        ['1234', '담은 블랙 [3병/6병/10병]', '낙지 볶음', '불닭볶음면', '떡볶이'],
#        ['1235', '낙안읍성 막걸리 X 2병', '간장 게장', '양념갈비', '찜닭'],
#        ['1236', '단감명작', '바지락 술찜', '크림 새우', '연어 스테이크'],
#        ['1237', '볼 빨간 막걸리 10%', '맥앤치즈', '돼지국밥', '닭곰탕'],
#        ['1238', '라이스 퐁당 13%', '백합조개탕', '초계국수', '물회'],
#        ['1239', '금풍양조 막걸리 X 4병', '메밀 전병', '도토리묵 무침', '두부김치'],
#        ['1241', '동학 1957', '들깨수제비', '궁중 떡볶이', '된장찌개'],
#        ['1242', '황금보리 25%', '크림 새우', '연어초밥', '꿔바로우'],
#        ['1246', '라라', '오징어 초무침', '뿌팟퐁커리', '생선까스'],
#        ['1247', '젤코바 감 와인', '까르보나라', '카프레제', '바스크 치즈 케이크'],
#        ['1248', '오디여라 25%', '크림소스 연어 스테이크', '양갈비 구이', '콘치즈'],
#        ['1249', '고리 진', '조개찜', '견과류', '크래커'],
#        ['1250', '이강주 25%', '떡갈비', '육전', '데리야끼 치킨'],
#        ['1251', '어미실 와인 화이트 스위트', '마라샹궈', '마카롱', '주꾸미 볶음'],
#        ['1252', '바텐더의 막걸리', '비포선셋', '밀키웨이', '화채펀치'],
#        ['1253', '얠로펀치', '팟타이', '하와이안 피자', '망고 아이스크림'],
#        ['1254', '오롯이 복숭아 스파클링 와인', '과일치즈', '애플 파이', '크로아상'],
#        ['1255', '오매락 25%', '막국수', '냉채 족발', '갈비 구이'],
#        ['1256', '7004S 키위와인', '새우튀김', '보쌈', '연어 스테이크'],
#        ['1257', '부자 막걸리 10%', '녹두전', '순대 볶음', '나가사키 짬뽕'],
#        ['1260', '왕주 40%', '초밥', '장어구이', '갈치조림'],
#        ['1261', '메밀로 25%', '막국수', '물회', '미나리 삼겹살'],
#        ['1262', '백제소주 25% X 2병', '고기국수', '닭곰탕', '나물 무침'],
#        ['1264', '감홍로', '호두파이', '곶감치즈말이', '호떡'],
#        ['1265', '아리아리 40%', '과일 샐러드', '월남쌈', '냉채 족발'],
#        ['1267', '여유 19%', '소 불고기', '제육 볶음', '콩나물 무침'],
#        ['1268', '참주가 솔 막걸리 [6병/12병]', '삼계탕', '버섯구이', '차돌박이 숙주 찜'],
#        ['1269', '참주가 라봉 막걸리 X 4병', '짜장면', '크림 파스타', '피자'],
#        ['1272', '주향소주 25%', '육전', '초밥', '순대'],
#        ['1274', '마크홀리 오리지널 6.0 [3병/6병]', '주꾸미 볶음', '멜론 프로슈토', '떡볶이'],
#        ['1275', '금산인삼주 수삼 43%', '연포탕', '삼계탕', '계란찜'],
#        ['1278', '강릉소주', '꼬막 무침', '물회', '해물 순두부'],
#        ['1279', '가평소주', '삼겹살', '목살구이', '버섯 볶음'],
#        ['1280', '당진소주', '고등어구이', '감자조림', '된장찌개'],
#        ['1287', '배금도가 포도막걸리', '초코 케이크', '마라탕', '오돌뼈'],
#        ['1288', '배금도가 포도약주', '찰보리빵', '블루베리 타르트', '제육볶음'],
#        ['1294', '주향소주 41%', '소갈비 찜', '매운탕', '딱새우 회'],
#        ['1295', '도봉산 막걸리 8% X 2병', '바지락 술찜', '수육', '차돌박이 숙주 볶음'],
#        ['1303', '추사백 40%', '흰살생선회', '삼치구이', '오징어 숙회'],
#        ['1308', '미르아토 청수 스위트 와인', '바지락 술찜', '연어샐러드', '문어 숙회'],
#        ['1309', '미르아토 로제 스파클링 스위트 와인', '에그타르트', '토스트', '로제 파스타'],
#        ['1321', '피에스 로제 스파클링 와인', '프로슈토', '올리브', '크림치즈'],
#        ['1322', '피에스 화이트 스파클링 와인', '리코타치즈', '시저 샐러드', '프로슈토'],
#        ['1326', '서울고량주 레드', '짜장면', '깐쇼새우', '꿔바로우'],
#        ['1327', '조은가', '돼지갈비 찜', '간장 치킨', '약밥'],
#        ['1338', '신례명주 50%', '양념갈비', '딱새우 회', '유산슬']], dtype='<U41')

# %%
df_sdh_food = pd.DataFrame(data = foodwrapper_list, columns= ["page","name","food1","food2","food3"])
df_sdh_food
# Out:
#      page             name   food1   food2    food3
# 0    1007         겨울소주 45%   버섯 전골     삼계탕      갈비찜
# 1    1008         진맥소주 53%      보쌈    장어구이  안심 스테이크
# 2    1013           이도 32%     삼겹살      곱창       족발
# 3    1014           이도 42%     불고기     닭갈비      해물탕
# 4    1015            감사 블루   고등어구이      육전   대패 삼겹살
# ..    ...              ...     ...     ...      ...
# 152  1321   피에스 로제 스파클링 와인    프로슈토     올리브     크림치즈
# 153  1322  피에스 화이트 스파클링 와인   리코타치즈  시저 샐러드     프로슈토
# 154  1326         서울고량주 레드     짜장면    깐쇼새우     꿔바로우
# 155  1327              조은가  돼지갈비 찜   간장 치킨       약밥
# 156  1338         신례명주 50%    양념갈비   딱새우 회      유산슬
#
# [157 rows x 5 columns]

# %%
# csv 파일로 내보내기

df_sdh_food.to_csv("sooldamhwa_food2.csv", index= False)

# %%
#csv 파일 확인
df_sdh_food1 = pd.read_csv("sooldamhwa_food2.csv")
df_sdh_food1
# Out:
#      page             name   food1   food2    food3
# 0    1007         겨울소주 45%   버섯 전골     삼계탕      갈비찜
# 1    1008         진맥소주 53%      보쌈    장어구이  안심 스테이크
# 2    1013           이도 32%     삼겹살      곱창       족발
# 3    1014           이도 42%     불고기     닭갈비      해물탕
# 4    1015            감사 블루   고등어구이      육전   대패 삼겹살
# ..    ...              ...     ...     ...      ...
# 152  1321   피에스 로제 스파클링 와인    프로슈토     올리브     크림치즈
# 153  1322  피에스 화이트 스파클링 와인   리코타치즈  시저 샐러드     프로슈토
# 154  1326         서울고량주 레드     짜장면    깐쇼새우     꿔바로우
# 155  1327              조은가  돼지갈비 찜   간장 치킨       약밥
# 156  1338         신례명주 50%    양념갈비   딱새우 회      유산슬
#
# [157 rows x 5 columns]

# %% [markdown]
# page만 새로 불러오기
#
# -> 불필요한 page는 굳이 돌릴 필요가 x

# %%
pagenum= df_sdh_food["page"]
pagenum
# Out:
# 0      1007
# 1      1008
# 2      1013
# 3      1014
# 4      1015
#        ...
# 152    1321
# 153    1322
# 154    1326
# 155    1327
# 156    1338
# Name: page, Length: 157, dtype: object

# %%
# page_lsit값을 따서 리스트 변환 -> int값으로 변환해줌

page_list2 = pagenum.values.tolist()
page_list2 = list(map(int, page_list2))
page_list2
# Out:
# [1007,
#  1008,
#  1013,
#  1014,
#  1015,
#  1016,
#  1018,
#  1019,
#  1020,
#  1021,
#  1037,
#  1043,
#  1049,
#  1050,
#  1051,
#  1052,
#  1054,
#  1055,
#  1057,
#  1058,
#  1059,
#  1060,
#  1061,
#  1062,
#  1063,
#  1064,
#  1065,
#  1070,
#  1071,
#  1072,
#  1074,
#  1085,
#  1092,
#  1093,
#  1094,
#  1095,
#  1096,
#  1098,
#  1099,
#  1100,
#  1101,
#  1102,
#  1105,
#  1106,
#  1107,
#  1109,
#  1110,
#  1111,
#  1112,
#  1113,
#  1115,
#  1116,
#  1118,
#  1119,
#  1122,
#  1123,
#  1124,
#  1125,
#  1126,
#  1128,
#  1129,
#  1132,
#  1134,
#  1136,
#  1137,
#  1138,
#  1139,
#  1140,
#  1142,
#  1147,
#  1149,
#  1150,
#  1154,
#  1156,
#  1157,
#  1158,
#  1164,
#  1165,
#  1166,
#  1167,
#  1169,
#  1170,
#  1171,
#  1177,
#  1178,
#  1187,
#  1188,
#  1189,
#  1190,
#  1191,
#  1196,
#  1198,
#  1199,
#  1201,
#  1202,
#  1203,
#  1205,
#  1207,
#  1212,
#  1214,
#  1216,
#  1217,
#  1219,
#  1220,
#  1221,
#  1223,
#  1224,
#  1225,
#  1227,
#  1230,
#  1231,
#  1234,
#  1235,
#  1236,
#  1237,
#  1238,
#  1239,
#  1241,
#  1242,
#  1246,
#  1247,
#  1248,
#  1249,
#  1250,
#  1251,
#  1252,
#  1253,
#  1254,
#  1255,
#  1256,
#  1257,
#  1260,
#  1261,
#  1262,
#  1264,
#  1265,
#  1267,
#  1268,
#  1269,
#  1272,
#  1274,
#  1275,
#  1278,
#  1279,
#  1280,
#  1287,
#  1288,
#  1294,
#  1295,
#  1303,
#  1308,
#  1309,
#  1321,
#  1322,
#  1326,
#  1327,
#  1338]

# %%
with open("page_list2.csv", 'w') as file:
  writer = csv.writer(file)
  writer.writerow(page_list2)

# %%
len(page_list2)
# Out:
# 157

# %% [markdown]
# ## ratestyle 크롤링

# %%
url = "https://www.sooldamhwa.com/damhwaMarket/detail/1013"

resp = requests.get(url)
html = BeautifulSoup(resp.text, "html.parser")
html.select("div.DetailSoolRatesStyle__Text-sc-1t255cq-1")
# Out:
# [<div class="DetailSoolRatesStyle__Text-sc-1t255cq-1 crplqU">강함</div>,
#  <div class="DetailSoolRatesStyle__Text-sc-1t255cq-1 crplqU">약함</div>,
#  <div class="DetailSoolRatesStyle__Text-sc-1t255cq-1 crplqU">강함</div>,
#  <div class="DetailSoolRatesStyle__Text-sc-1t255cq-1 crplqU">강함</div>,
#  <div class="DetailSoolRatesStyle__Text-sc-1t255cq-1 crplqU">강함</div>]

# %% [markdown]
# ratestyle_label,text 각 다섯개

# %%
html.select("div.DetailSoolRatesStyle__Label-sc-1t255cq-2")
# Out:
# [<div class="DetailSoolRatesStyle__Label-sc-1t255cq-2 VWfA">고소한 향</div>,
#  <div class="DetailSoolRatesStyle__Label-sc-1t255cq-2 VWfA">화사한 향</div>,
#  <div class="DetailSoolRatesStyle__Label-sc-1t255cq-2 VWfA">맛의 강도</div>,
#  <div class="DetailSoolRatesStyle__Label-sc-1t255cq-2 VWfA">바디감</div>,
#  <div class="DetailSoolRatesStyle__Label-sc-1t255cq-2 VWfA">매운맛</div>]

# %%
ratestyle_list = []

for page in page_list2 :
    #time sleep   
    seed = np.random.randint(100)
    np.random.seed(seed)
    a = np.random.randint(3) 
    time.sleep(a)
    # url 설정
    url = f"https://www.sooldamhwa.com/damhwaMarket/detail/{page}"
        # requests로 데이터 요청하기
    resp = requests.get(url)
    html = BeautifulSoup(resp.text, "html.parser")

    if not html.select("div.DetailSoolRatesStyle__Label-sc-1t255cq-2") :
        print(f"{page}페이지 오류!")

    elif resp.status_code == requests.codes.ok:
        print(f"{page}페이지 크롤링 중입니다.")
        # page 숫자 추가
        ratestyle_list.append(f"{page}")
        # 술 이름 추가
        liquorname = html.select("div.productName")[0].text
        ratestyle_list.append(liquorname)
        # 라벨 데이터 선별
        for label in html.select("div.DetailSoolRatesStyle__Label-sc-1t255cq-2")[:5] :
            ratestyle_list.append(label.text)
        # 텍스트 데이터 선별
        for t in html.select("div.DetailSoolRatesStyle__Text-sc-1t255cq-1")[:5] :
            ratestyle_list.append(t.text)

         
print("크롤링 완료!")
# Out:
# 1007페이지 크롤링 중입니다.
# 1008페이지 크롤링 중입니다.
# 1013페이지 크롤링 중입니다.
# 1014페이지 크롤링 중입니다.
# 1015페이지 크롤링 중입니다.
# 1016페이지 크롤링 중입니다.
# 1018페이지 크롤링 중입니다.
# 1019페이지 크롤링 중입니다.
# 1020페이지 크롤링 중입니다.
# 1021페이지 크롤링 중입니다.
# 1037페이지 크롤링 중입니다.
# 1043페이지 크롤링 중입니다.
# 1049페이지 크롤링 중입니다.
# 1050페이지 크롤링 중입니다.
# 1051페이지 크롤링 중입니다.
# 1052페이지 크롤링 중입니다.
# 1054페이지 크롤링 중입니다.
# 1055페이지 크롤링 중입니다.
# 1057페이지 크롤링 중입니다.
# 1058페이지 크롤링 중입니다.
# 1059페이지 크롤링 중입니다.
# 1060페이지 크롤링 중입니다.
# 1061페이지 크롤링 중입니다.
# 1062페이지 크롤링 중입니다.
# 1063페이지 크롤링 중입니다.
# 1064페이지 크롤링 중입니다.
# 1065페이지 크롤링 중입니다.
# 1070페이지 크롤링 중입니다.
# 1071페이지 크롤링 중입니다.
# 1072페이지 크롤링 중입니다.
# 1074페이지 크롤링 중입니다.
# 1085페이지 크롤링 중입니다.
# 1092페이지 크롤링 중입니다.
# 1093페이지 크롤링 중입니다.
# 1094페이지 크롤링 중입니다.
# 1095페이지 크롤링 중입니다.
# 1096페이지 크롤링 중입니다.
# 1098페이지 크롤링 중입니다.
# 1099페이지 크롤링 중입니다.
# 1100페이지 크롤링 중입니다.
# 1101페이지 크롤링 중입니다.
# 1102페이지 크롤링 중입니다.
# 1105페이지 크롤링 중입니다.
# 1106페이지 크롤링 중입니다.
# 1107페이지 크롤링 중입니다.
# 1109페이지 크롤링 중입니다.
# 1110페이지 크롤링 중입니다.
# 1111페이지 크롤링 중입니다.
# 1112페이지 크롤링 중입니다.
# 1113페이지 크롤링 중입니다.
# 1115페이지 크롤링 중입니다.
# 1116페이지 크롤링 중입니다.
# 1118페이지 크롤링 중입니다.
# 1119페이지 크롤링 중입니다.
# 1122페이지 크롤링 중입니다.
# 1123페이지 크롤링 중입니다.
# 1124페이지 크롤링 중입니다.
# 1125페이지 크롤링 중입니다.
# 1126페이지 크롤링 중입니다.
# 1128페이지 크롤링 중입니다.
# 1129페이지 크롤링 중입니다.
# 1132페이지 크롤링 중입니다.
# 1134페이지 크롤링 중입니다.
# 1136페이지 크롤링 중입니다.
# 1137페이지 크롤링 중입니다.
# 1138페이지 크롤링 중입니다.
# 1139페이지 크롤링 중입니다.
# 1140페이지 크롤링 중입니다.
# 1142페이지 크롤링 중입니다.
# 1147페이지 크롤링 중입니다.
# 1149페이지 크롤링 중입니다.
# 1150페이지 크롤링 중입니다.
# 1154페이지 크롤링 중입니다.
# 1156페이지 크롤링 중입니다.
# 1157페이지 크롤링 중입니다.
# 1158페이지 크롤링 중입니다.
# 1164페이지 크롤링 중입니다.
# 1165페이지 크롤링 중입니다.
# 1166페이지 크롤링 중입니다.
# 1167페이지 크롤링 중입니다.
# 1169페이지 크롤링 중입니다.
# 1170페이지 크롤링 중입니다.
# 1171페이지 크롤링 중입니다.
# 1177페이지 크롤링 중입니다.
# 1178페이지 크롤링 중입니다.
# 1187페이지 크롤링 중입니다.
# 1188페이지 크롤링 중입니다.
# 1189페이지 크롤링 중입니다.
# 1190페이지 크롤링 중입니다.
# 1191페이지 크롤링 중입니다.
# 1196페이지 크롤링 중입니다.
# 1198페이지 크롤링 중입니다.
# 1199페이지 크롤링 중입니다.
# 1201페이지 크롤링 중입니다.
# 1202페이지 크롤링 중입니다.
# 1203페이지 크롤링 중입니다.
# 1205페이지 크롤링 중입니다.
# 1207페이지 크롤링 중입니다.
# 1212페이지 크롤링 중입니다.
# 1214페이지 크롤링 중입니다.
# 1216페이지 크롤링 중입니다.
# 1217페이지 크롤링 중입니다.
# 1219페이지 크롤링 중입니다.
# 1220페이지 크롤링 중입니다.
# 1221페이지 크롤링 중입니다.
# 1223페이지 크롤링 중입니다.
# 1224페이지 크롤링 중입니다.
# 1225페이지 크롤링 중입니다.
# 1227페이지 크롤링 중입니다.
# 1230페이지 크롤링 중입니다.
# 1231페이지 크롤링 중입니다.
# 1234페이지 크롤링 중입니다.
# 1235페이지 크롤링 중입니다.
# 1236페이지 크롤링 중입니다.
# 1237페이지 크롤링 중입니다.
# 1238페이지 크롤링 중입니다.
# 1239페이지 크롤링 중입니다.
# 1241페이지 크롤링 중입니다.
# 1242페이지 크롤링 중입니다.
# 1246페이지 크롤링 중입니다.
# 1247페이지 크롤링 중입니다.
# 1248페이지 크롤링 중입니다.
# 1249페이지 크롤링 중입니다.
# 1250페이지 크롤링 중입니다.
# 1251페이지 크롤링 중입니다.
# 1252페이지 크롤링 중입니다.
# 1253페이지 크롤링 중입니다.
# 1254페이지 크롤링 중입니다.
# 1255페이지 크롤링 중입니다.
# 1256페이지 크롤링 중입니다.
# 1257페이지 크롤링 중입니다.
# 1260페이지 크롤링 중입니다.
# 1261페이지 크롤링 중입니다.
# 1262페이지 크롤링 중입니다.
# 1264페이지 크롤링 중입니다.
# 1265페이지 크롤링 중입니다.
# 1267페이지 크롤링 중입니다.
# 1268페이지 크롤링 중입니다.
# 1269페이지 크롤링 중입니다.
# 1272페이지 크롤링 중입니다.
# 1274페이지 크롤링 중입니다.
# 1275페이지 크롤링 중입니다.
# 1278페이지 크롤링 중입니다.
# 1279페이지 크롤링 중입니다.
# 1280페이지 크롤링 중입니다.
# 1287페이지 크롤링 중입니다.
# 1288페이지 크롤링 중입니다.
# 1294페이지 크롤링 중입니다.
# 1295페이지 크롤링 중입니다.
# 1303페이지 크롤링 중입니다.
# 1308페이지 크롤링 중입니다.
# 1309페이지 크롤링 중입니다.
# 1321페이지 크롤링 중입니다.
# 1322페이지 크롤링 중입니다.
# 1326페이지 크롤링 중입니다.
# 1327페이지 크롤링 중입니다.
# 1338페이지 크롤링 중입니다.
# 크롤링 완료!

# %% [markdown]
# ### rate df 변환 후 csv 저장!!

# %%
ratestyle_list1 = np.array(ratestyle_list).reshape(-1,12)
ratestyle_list1
# Out:
# array([['1007', '겨울소주 45%', '고소한 향', ..., '강함', '강함', '강함'],
#        ['1008', '진맥소주 53%', '고소한 향', ..., '매우강함', '매우강함', '매우강함'],
#        ['1013', '이도 32%', '고소한 향', ..., '강함', '강함', '강함'],
#        ...,
#        ['1326', '서울고량주 레드', '고소한 향', ..., '중간', '중간', '중간'],
#        ['1327', '조은가', '고소한 향', ..., '강함', '강함', '중간'],
#        ['1338', '신례명주 50%', '고소한 향', ..., '매우강함', '강함', '매우강함']],
#       dtype='<U41')

# %%
df_sdh_rate = pd.DataFrame(data = ratestyle_list1, columns= ["page","name","label1","label2","label3","label4","label5","text1","text2","text3","text4","text5"])
df_sdh_rate[6:16]
# Out:
#     page             name label1 label2 label3 label4 label5 text1 text2  \
# 6   1018           미르 54%  고소한 향  화사한 향  맛의 강도    바디감    매운맛    강함  매우약함
# 7   1019      문경바람 백자 25%  고소한 향  화사한 향  맛의 강도    바디감    매운맛  매우약함    중간
# 8   1020         고소리술 40%  고소한 향  화사한 향  맛의 강도    바디감    매운맛    강함  매우약함
# 9   1021      문경바람 오크 25%  고소한 향  화사한 향  맛의 강도    바디감    매운맛  매우약함    중간
# 10  1037         오메기술 15%     단맛     산미     씁쓸    바디감     담백    중간    약함
# 11  1043           만월 24%  고소한 향  화사한 향  맛의 강도    바디감    매운맛    없음    강함
# 12  1049               금설  고소한 향  화사한 향  맛의 강도    바디감    매운맛    강함    약함
# 13  1050               한청     단맛     산미     씁쓸    바디감     담백    중간    중간
# 14  1051           궁중술 왕주     단맛     산미     씁쓸    바디감     담백    중간    중간
# 15  1052  대대포 블루 [8병/12병]     단맛     산미     담백    바디감     탄산    중간    약함
#
#    text3 text4 text5
# 6   매우강함  매우강함  매우강함
# 7     중간    중간    중간
# 8     강함  매우강함    강함
# 9     중간    중간    중간
# 10  매우약함    중간    강함
# 11    중간    중간    중간
# 12    강함    강함    강함
# 13    약함    중간    중간
# 14    약함    중간    중간
# 15    중간    약함    없음

# %%
df_sdh_rate.to_csv("sooldamhwa_rate2.csv", index= False)

# %% [markdown]
# # 리뷰 크롤링

# %%
# 리뷰 많은 순 정렬했을 때 가장 많은 게 331개
# 제품 pagelist는 위와 동일!

# %%
url = "https://api.sooldamhwa.com/product/review/1020?limit=20&order=latest"
header = {     
          'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'
         }
resp = requests.get(url, headers = header)
data = json.loads(resp.text)
df = pd.DataFrame(data['result'])
df
# Out:
#        id    type  maker_id  product_id  product_option_id product_name  \
# 0  318311  market        13        1020               1118     고소리술 40%
# 1  179220  market        13        1020               1118     고소리술 40%
# 2  299591  market        13        1020               1118     고소리술 40%
# 3  291160  market        13        1020               1118     고소리술 40%
# 4  205055  market        13        1020               1118     고소리술 40%
# 5  225365  market        13        1020               1118     고소리술 40%
# 6  225216  market        13        1020               1118     고소리술 40%
# 7  214098  market        13        1020               1118     고소리술 40%
# 8  159973  market        13        1020               1118     고소리술 40%
# 9  159429  market        13        1020               1118     고소리술 40%
#
#   product_option_name                                  product_thumbnail  \
# 0    l] 고소리술 40%  https://sooldamhwa-static-files.s3.ap-northeas...
# 1    l] 고소리술 40%  https://sooldamhwa-static-files.s3.ap-northeas...
# 2    l] 고소리술 40%  https://sooldamhwa-static-files.s3.ap-northeas...
# 3    l] 고소리술 40%  https://sooldamhwa-static-files.s3.ap-northeas...
# 4    l] 고소리술 40%  https://sooldamhwa-static-files.s3.ap-northeas...
# 5    l] 고소리술 40%  https://sooldamhwa-static-files.s3.ap-northeas...
# 6    l] 고소리술 40%  https://sooldamhwa-static-files.s3.ap-northeas...
# 7    l] 고소리술 40%  https://sooldamhwa-static-files.s3.ap-northeas...
# 8    l] 고소리술 40%  https://sooldamhwa-static-files.s3.ap-northeas...
# 9    l] 고소리술 40%  https://sooldamhwa-static-files.s3.ap-northeas...
#
#    score                                            comment  ... flavor_score  \
# 0    5.0                                       빠른 배송 감사합니다.  ...          4.0
# 1    3.5                                기대했던거에 비해서는 약간 아쉽네요  ...          3.0
# 2    5.0                          증류주 중 최고~목넘김과 향 모든게 조하요!!  ...          0.0
# 3    5.0               첫향에서 장향이 나고 맛에서는 달큰한 건포도나 건무화과맛이 난다.  ...          5.0
# 4    5.0                                                     ...          0.0
# 5    5.0  고소한 맛이 일품이네요. 누룽지 향이 아주 강하게 올라옵니다. 안주 없이 스트레이트...  ...          4.0
# 6    5.0  처음에 선물용 도자기병이 탐나서 주문하였다.\n독하다는 느낌과 향이 조금 세다 이렇...  ...          3.5
# 7    4.0                                                     ...          0.0
# 8    4.0  새로운 풍미의 전통주를 고르는 재미~~\n 첫맛은 누룩인지 ~~ 터벅한 맛~~\n호...  ...          4.0
# 9    5.0                                                     ...          0.0
#
#    design_score  delivery_score  with_who to_who step  status  \
# 0           4.5             5.0    family           3    show
# 1           4.0             5.0    friend           3    show
# 2           0.0             0.0                     2    show
# 3           5.0             4.5     alone           4    show
# 4           0.0             0.0                     1    show
# 5           3.5             5.0     alone           4    show
# 6           5.0             5.0    friend           4    show
# 7           0.0             0.0                     1    show
# 8           5.0             5.0     alone           4    show
# 9           0.0             0.0                     1    None
#
#                  written_at                created_at  \
# 0  2022-09-03T09:55:59.000Z  2022-09-03T09:55:22.000Z
# 1  2022-09-03T07:37:31.000Z  2021-10-07T06:11:20.000Z
# 2  2022-08-19T02:21:51.000Z  2022-08-18T00:52:42.000Z
# 3  2022-07-18T12:42:56.000Z  2022-07-17T10:36:27.000Z
# 4  2022-03-23T13:07:35.000Z  2021-12-14T16:10:25.000Z
# 5  2022-03-16T02:27:05.000Z  2022-03-16T02:24:08.000Z
# 6  2022-03-11T13:42:54.000Z  2022-03-11T13:34:06.000Z
# 7  2022-01-02T12:33:56.000Z  2022-01-02T12:33:49.000Z
# 8  2021-08-21T02:01:17.000Z  2021-08-16T01:45:47.000Z
# 9  2021-08-19T02:43:44.000Z  2021-08-03T09:30:25.000Z
#
#                                    user
# 0     {'name': '원용훈', 'nickname': None}
# 1     {'name': '조성근', 'nickname': None}
# 2     {'name': '이예령', 'nickname': None}
# 3  {'name': '이종복', 'nickname': '술잔의향기'}
# 4     {'name': '양혜정', 'nickname': None}
# 5   {'name': '이건혁', 'nickname': '독주공방'}
# 6     {'name': '임주엽', 'nickname': None}
# 7     {'name': '박영빈', 'nickname': None}
# 8     {'name': '안수윤', 'nickname': None}
# 9     {'name': '김종덕', 'nickname': None}
#
# [10 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'type', 'maker_id', 'product_id', 'product_option_id',
#        'product_name', 'product_option_name', 'product_thumbnail', 'score',
#        'comment', 'img_urls', 'flavor_score', 'design_score', 'delivery_score',
#        'with_who', 'to_who', 'step', 'status', 'written_at', 'created_at',
#        'user'],
#       dtype='object')

# %%
# page_list 다시 불러오기

with open('page_list2.csv', 'r') as f:
    reader = csv.reader(f)
    page_list2 = list(reader)
page_list2 = page_list2[0]
page_list2
# Out:
# ['1007',
#  '1008',
#  '1013',
#  '1014',
#  '1015',
#  '1016',
#  '1018',
#  '1019',
#  '1020',
#  '1021',
#  '1037',
#  '1043',
#  '1049',
#  '1050',
#  '1051',
#  '1052',
#  '1054',
#  '1055',
#  '1057',
#  '1058',
#  '1059',
#  '1060',
#  '1061',
#  '1062',
#  '1063',
#  '1064',
#  '1065',
#  '1070',
#  '1071',
#  '1072',
#  '1074',
#  '1085',
#  '1092',
#  '1093',
#  '1094',
#  '1095',
#  '1096',
#  '1098',
#  '1099',
#  '1100',
#  '1101',
#  '1102',
#  '1105',
#  '1106',
#  '1107',
#  '1109',
#  '1110',
#  '1111',
#  '1112',
#  '1113',
#  '1115',
#  '1116',
#  '1118',
#  '1119',
#  '1122',
#  '1123',
#  '1124',
#  '1125',
#  '1126',
#  '1128',
#  '1129',
#  '1132',
#  '1134',
#  '1136',
#  '1137',
#  '1138',
#  '1139',
#  '1140',
#  '1142',
#  '1147',
#  '1149',
#  '1150',
#  '1154',
#  '1156',
#  '1157',
#  '1158',
#  '1164',
#  '1165',
#  '1166',
#  '1167',
#  '1169',
#  '1170',
#  '1171',
#  '1177',
#  '1178',
#  '1187',
#  '1188',
#  '1189',
#  '1190',
#  '1191',
#  '1196',
#  '1198',
#  '1199',
#  '1201',
#  '1202',
#  '1203',
#  '1205',
#  '1207',
#  '1212',
#  '1214',
#  '1216',
#  '1217',
#  '1219',
#  '1220',
#  '1221',
#  '1223',
#  '1224',
#  '1225',
#  '1227',
#  '1230',
#  '1231',
#  '1234',
#  '1235',
#  '1236',
#  '1237',
#  '1238',
#  '1239',
#  '1241',
#  '1242',
#  '1246',
#  '1247',
#  '1248',
#  '1249',
#  '1250',
#  '1251',
#  '1252',
#  '1253',
#  '1254',
#  '1255',
#  '1256',
#  '1257',
#  '1260',
#  '1261',
#  '1262',
#  '1264',
#  '1265',
#  '1267',
#  '1268',
#  '1269',
#  '1272',
#  '1274',
#  '1275',
#  '1278',
#  '1279',
#  '1280',
#  '1287',
#  '1288',
#  '1294',
#  '1295',
#  '1303',
#  '1308',
#  '1309',
#  '1321',
#  '1322',
#  '1326',
#  '1327',
#  '1338']

# %% [markdown]
# ### dataframe 생성

# %%
# 사용할 컬럼만 살려서 빈 데이터 프레임 만들기 -> 컬럼 4개
# 컬럼 순서가 뒤죽박죽으로 들어오지만, 중요하지 않아 그대로 진행하기로

df_sdh_review = pd.DataFrame(columns = {'product_id','product_name','score','comment','user'})

# %%
df_sdh_review
# Out:
# Empty DataFrame
# Columns: [score, comment, product_id, user, product_name]
# Index: []

# %%
header = {     
          'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'
         }
         
for page in page_list2 :
    #time sleep   
    seed = np.random.randint(100)
    np.random.seed(seed)
    a = np.random.randint(3) 
    time.sleep(a)
    # url 설정
    url = f"https://api.sooldamhwa.com/product/review/{page}?limit=350&order=latest"
    # requests로 데이터 요청하기
    resp = requests.get(url,headers= header)
    data = json.loads(resp.text)
    
    if not data['result'] : 
        # 리뷰가 없는 페이지 지나치기
        print(f"{page}페이지 리뷰 없음")
    else :
        df = pd.DataFrame(data['result'])
        # 쓰지 않는 column 드랍
        df.drop(columns={'id','type','maker_id','product_option_id','product_option_name','product_thumbnail','img_urls','flavor_score','design_score','delivery_score','with_who','to_who','step','status','written_at','created_at'}, inplace=True)
        df_sdh_review = df_sdh_review.append(df, ignore_index = True)
        print(f"{page} 페이지 리뷰 추가!")

         
print("크롤링 완료!")
# Out:
# 1007 페이지 리뷰 추가!
# 1008페이지 리뷰 없음
# 1013 페이지 리뷰 추가!
# 1014 페이지 리뷰 추가!
# 1015 페이지 리뷰 추가!
# 1016 페이지 리뷰 추가!
# 1018 페이지 리뷰 추가!
# 1019 페이지 리뷰 추가!
# 1020 페이지 리뷰 추가!
# 1021 페이지 리뷰 추가!
# 1037 페이지 리뷰 추가!
# 1043 페이지 리뷰 추가!
# 1049 페이지 리뷰 추가!
# 1050 페이지 리뷰 추가!
# 1051 페이지 리뷰 추가!
# 1052 페이지 리뷰 추가!
# 1054 페이지 리뷰 추가!
# 1055 페이지 리뷰 추가!
# 1057 페이지 리뷰 추가!
# 1058 페이지 리뷰 추가!
# 1059 페이지 리뷰 추가!
# 1060 페이지 리뷰 추가!
# 1061 페이지 리뷰 추가!
# 1062 페이지 리뷰 추가!
# 1063 페이지 리뷰 추가!
# 1064 페이지 리뷰 추가!
# 1065 페이지 리뷰 추가!
# 1070 페이지 리뷰 추가!
# 1071 페이지 리뷰 추가!
# 1072 페이지 리뷰 추가!
# 1074 페이지 리뷰 추가!
# 1085 페이지 리뷰 추가!
# 1092 페이지 리뷰 추가!
# 1093 페이지 리뷰 추가!
# 1094 페이지 리뷰 추가!
# 1095 페이지 리뷰 추가!
# 1096 페이지 리뷰 추가!
# 1098 페이지 리뷰 추가!
# 1099 페이지 리뷰 추가!
# 1100페이지 리뷰 없음
# 1101 페이지 리뷰 추가!
# 1102 페이지 리뷰 추가!
# 1105 페이지 리뷰 추가!
# 1106 페이지 리뷰 추가!
# 1107 페이지 리뷰 추가!
# 1109 페이지 리뷰 추가!
# 1110 페이지 리뷰 추가!
# 1111 페이지 리뷰 추가!
# 1112 페이지 리뷰 추가!
# 1113 페이지 리뷰 추가!
# 1115 페이지 리뷰 추가!
# 1116 페이지 리뷰 추가!
# 1118 페이지 리뷰 추가!
# 1119 페이지 리뷰 추가!
# 1122 페이지 리뷰 추가!
# 1123 페이지 리뷰 추가!
# 1124 페이지 리뷰 추가!
# 1125페이지 리뷰 없음
# 1126 페이지 리뷰 추가!
# 1128 페이지 리뷰 추가!
# 1129 페이지 리뷰 추가!
# 1132 페이지 리뷰 추가!
# 1134 페이지 리뷰 추가!
# 1136 페이지 리뷰 추가!
# 1137 페이지 리뷰 추가!
# 1138 페이지 리뷰 추가!
# 1139 페이지 리뷰 추가!
# 1140 페이지 리뷰 추가!
# 1142 페이지 리뷰 추가!
# 1147 페이지 리뷰 추가!
# 1149 페이지 리뷰 추가!
# 1150 페이지 리뷰 추가!
# 1154페이지 리뷰 없음
# 1156페이지 리뷰 없음
# 1157 페이지 리뷰 추가!
# 1158 페이지 리뷰 추가!
# 1164 페이지 리뷰 추가!
# 1165 페이지 리뷰 추가!
# 1166 페이지 리뷰 추가!
# 1167 페이지 리뷰 추가!
# 1169 페이지 리뷰 추가!
# 1170 페이지 리뷰 추가!
# 1171 페이지 리뷰 추가!
# 1177 페이지 리뷰 추가!
# 1178 페이지 리뷰 추가!
# 1187 페이지 리뷰 추가!
# 1188 페이지 리뷰 추가!
# 1189 페이지 리뷰 추가!
# 1190 페이지 리뷰 추가!
# 1191페이지 리뷰 없음
# 1196 페이지 리뷰 추가!
# 1198 페이지 리뷰 추가!
# 1199 페이지 리뷰 추가!
# 1201 페이지 리뷰 추가!
# 1202 페이지 리뷰 추가!
# 1203 페이지 리뷰 추가!
# 1205 페이지 리뷰 추가!
# 1207 페이지 리뷰 추가!
# 1212 페이지 리뷰 추가!
# 1214 페이지 리뷰 추가!
# 1216 페이지 리뷰 추가!
# 1217 페이지 리뷰 추가!
# 1219 페이지 리뷰 추가!
# 1220 페이지 리뷰 추가!
# 1221 페이지 리뷰 추가!
# 1223 페이지 리뷰 추가!
# 1224 페이지 리뷰 추가!
# 1225 페이지 리뷰 추가!
# 1227 페이지 리뷰 추가!
# 1230 페이지 리뷰 추가!
# 1231 페이지 리뷰 추가!
# 1234 페이지 리뷰 추가!
# 1235 페이지 리뷰 추가!
# 1236 페이지 리뷰 추가!
# 1237 페이지 리뷰 추가!
# 1238 페이지 리뷰 추가!
# 1239 페이지 리뷰 추가!
# 1241 페이지 리뷰 추가!
# 1242 페이지 리뷰 추가!
# 1246페이지 리뷰 없음
# 1247 페이지 리뷰 추가!
# 1248 페이지 리뷰 추가!
# 1249 페이지 리뷰 추가!
# 1250 페이지 리뷰 추가!
# 1251 페이지 리뷰 추가!
# 1252 페이지 리뷰 추가!
# 1253 페이지 리뷰 추가!
# 1254 페이지 리뷰 추가!
# 1255 페이지 리뷰 추가!
# 1256 페이지 리뷰 추가!
# 1257 페이지 리뷰 추가!
# 1260 페이지 리뷰 추가!
# 1261 페이지 리뷰 추가!
# 1262 페이지 리뷰 추가!
# 1264 페이지 리뷰 추가!
# 1265페이지 리뷰 없음
# 1267 페이지 리뷰 추가!
# 1268 페이지 리뷰 추가!
# 1269페이지 리뷰 없음
# 1272 페이지 리뷰 추가!
# 1274 페이지 리뷰 추가!
# 1275 페이지 리뷰 추가!
# 1278 페이지 리뷰 추가!
# 1279 페이지 리뷰 추가!
# 1280 페이지 리뷰 추가!
# 1287 페이지 리뷰 추가!
# 1288 페이지 리뷰 추가!
# 1294 페이지 리뷰 추가!
# 1295페이지 리뷰 없음
# 1303 페이지 리뷰 추가!
# 1308페이지 리뷰 없음
# 1309페이지 리뷰 없음
# 1321페이지 리뷰 없음
# 1322페이지 리뷰 없음
# 1326 페이지 리뷰 추가!
# 1327페이지 리뷰 없음
# 1338페이지 리뷰 없음
# 크롤링 완료!

# %%
df_sdh_review
# Out:
#       score                                            comment product_id  \
# 0       5.0                                                          1007
# 1       4.5                                   이름값 하는 깔끔한 맛입니다.       1007
# 2       5.0  증류소주에 기본을 보여 주는 술 .\n부드러운 첫 입맛, 묵직한 마무리와 중간에 목...       1007
# 3       3.5                                                          1007
# 4       5.0                               역시는 역시군요 다음에 또 구매할께요       1007
# ...     ...                                                ...        ...
# 1721    5.0  사과향이 진하고 마실 때 목넘김이 좋지만 40도라 그런지 알콜향 후폭풍이 조금 있어...       1303
# 1722    4.5                                    배송빠르고 맛이 기대되네요.       1326
# 1723    5.0  고량주 마시고 나서 나는 먹을게 아닌 듯한 꿉꿉한 향이 양하대곡 보다 덜 합니다. ...       1326
# 1724    5.0  지난달에 담화박스로 받아보고 너무 마음에 들어서 개별로 구매했네요 달큰한 첫맛과 고...       1326
# 1725    5.0                                        조은 제품 감사합니다       1326
#
#                                        user                product_name
# 0          {'name': '김성광중', 'nickname': ''}  겨울소주 45% [증정 이벤트 상세페이지 참고]
# 1         {'name': '김성애', 'nickname': None}                    겨울소주 45%
# 2         {'name': '원용훈', 'nickname': None}                    겨울소주 45%
# 3     {'name': '진병언', 'nickname': 'pang21'}                    겨울소주 45%
# 4        {'name': '박기현', 'nickname': '양둥이'}                    겨울소주 45%
# ...                                     ...                         ...
# 1721     {'name': '정지우', 'nickname': '꽃지우'}                     추사백 40%
# 1722      {'name': '박진호', 'nickname': None}                    서울고량주 레드
# 1723    {'name': '문대양', 'nickname': '숨은고수'}                    서울고량주 레드
# 1724     {'name': '김태우', 'nickname': '에버튼'}                    서울고량주 레드
# 1725     {'name': '이재민', 'nickname': '이재민'}                    서울고량주 레드
#
# [1726 rows x 5 columns]

# %%
df_sdh_review.to_csv("sooldamhwa_review2.csv", index= False)
