# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
woorisool = pd.read_csv('./woorisool_product_list.csv')
woorisool
# Out:
#      Unnamed: 0              produc_name alcholicity  \
# 0             0   애플 상그리아 6.3도 750ml+케이스          레드
# 1             1                  진로 토닉워터         페트병
# 2             2                 오미자 생막걸리        6.5%
# 3             3     민속주왕주 13도 700ml 선물세트         13%
# 4             4  김보성의 의리남 소주 16.5도 360ml       16.5%
# ..          ...                      ...         ...
# 374         374       추성고을 추성주 25도 400ml         25%
# 375         375       추성고을 추성주 25도 350ml         25%
# 376         376            이강주 19도 375ml         19%
# 377         377  전주 이강주 1호 25도 400ml 도자기         25%
# 378         378              금산인삼주 수삼 23         23%
#
#                                               capacity  price  \
# 0                                                 부드러움  22900
# 1    상품정보 제공고시제품명상품상세참조식품의 유형상품상세참조생산자상품상세참조소재지상품상세...    800
# 2                                                750ml   2800
# 3                                               1400ml  36500
# ...

# %%
naverwiki = pd.read_csv('./naver_wiki_total.csv')
naverwiki
# Out:
#      Unnamed: 0            제품명   향기   단맛   신맛  청량감  바디감  목넘김  균형감
# 0             0  1000억막걸리프리바이오  NaN  3.0  4.0  3.0  3.0  NaN  NaN
# 1             1    1000억유산균막걸리  NaN  3.0  5.0  5.0  3.0  NaN  NaN
# 2             2  1932새싹땅콩햅쌀막걸리  NaN  2.0  2.0  3.0  5.0  NaN  NaN
# 3             3  1932새싹땅콩흑미막걸리  NaN  3.0  1.0  1.0  4.0  NaN  NaN
# 4             4           33JU  4.0  3.0  NaN  NaN  1.0  1.0  NaN
# ..          ...            ...  ...  ...  ...  ...  ...  ...  ...
# 541         541       희양산막걸리9%  NaN  2.0  3.0  2.0  3.0  NaN  NaN
# 542         542       DMZ240km  1.0  2.0  NaN  NaN  3.0  NaN  NaN
# 543         543        g12골디락스  NaN  2.0  2.0  2.0  3.0  NaN  3.0
# 544         544        우도땅콩전통주  NaN  4.0  1.0  3.0  3.0  NaN  NaN
# 545         545     The찾을수록시리즈  NaN  4.0  2.0  3.0  2.0  NaN  NaN
#
# [546 rows x 9 columns]

# %%
woorisool_list = woorisool['produc_name'].values.tolist()

# %%
print(type(woorisool_list))
woorisool_list
# Out:
# <class 'list'>
# ['애플 상그리아 6.3도 750ml+케이스',
#  '진로 토닉워터',
#  '오미자 생막걸리',
#  '민속주왕주 13도 700ml 선물세트',
#  '김보성의 의리남 소주 16.5도 360ml',
#  '이강주 선물세트 29호 25도',
#  '맑은내일 유자',
#  '추성주 흑자 도자기 선물세트',
#  '특2호 선물세트',
#  '문배술 특1호세트 40도 400ml',
#  '양반안동소주 선물세트 연꽃 흑자 45도 600ml+전용잔 1개',
#  '우희열 명인 한산소곡주 어주 선물세트 18도 700ml  잔 2개',
#  '안동소주 일품 특2호 선물세트  40도 400ml x 2병',
#  '문배술 헤리티지 세트 25도 375ml',
#  '한주양조 서각 25도 400ml + 잔 2EA + 쇼핑백',
#  '우리술상회 3본입 손잡이 케이스 선물상자',
#  '영덕주조 블링블링 주간감성 노을별 15도 360ml',
#  '영덕주조 블링블링 주간감성 바다별 15도 360ml',
#  '꿀에는 열매가 한가득 모음 오늘도수고했어오미자 도원결의15호랑이 미상25 잭스허니',
#  '중원당 청명주 백도자기세트',
#  '한주양주 매화 35도 700ml',
#  '꿀처럼 끈끈한 우정 모음 의리남 동해소주 밀담 잭스허니',
#  '전통주를 추석을 감싸드리는 선물 모음 추성주주간감성 375ml보자기',
#  '블랙홀 온더락 모음 럼PHAT42블랙 진안블랙18도 도원결의15 안동소주일품40 아이스볼메이커',
#  '집들이 선물 모음 럼PHAT블랙42도 추사백25주간감성 도원결의15 의리남소주 우리술상회종이쇼핑백',
#  '[내변산] 오디와인 미니어처 세트 13도 90ml 5병+쇼핑백',
#  '내변산 양조장 반달곰이 품은 부안참뽕와인 13도 375ml 2병',
#  '죽향41 골드라벨',
#  '죽향41 실버라벨',
#  '백제소주',
#  '꿀과 시원하게 의리남소주 한잔해~ 모음 의리남+잭스허니+왕아이스볼+온더락',
# ...

# %%
naverwiki_list = naverwiki['제품명'].values.tolist()

# %%
print(type(naverwiki_list))
naverwiki_list
# Out:
# <class 'list'>
# ['1000억막걸리프리바이오',
#  '1000억유산균막걸리',
#  '1932새싹땅콩햅쌀막걸리',
#  '1932새싹땅콩흑미막걸리',
#  '33JU',
#  '52C',
#  '가덕순쌀막걸리',
#  '가을빛레드와인',
#  '가평잣생막걸리',
#  '감그린레귤러',
#  '감그린스페셜',
#  '감그린아이스와인',
#  '감보드카',
#  '감사',
#  '감아락 25',
#  '감악산머루주',
#  '감이슬',
#  '감자술13%',
#  '감홍로백자',
#  '감홍로청자',
#  '강소주',
#  '강쇠',
#  '걍즐겨',
#  '겨울소주25',
#  '계룡백일주12년',
#  '계룡백일주16%',
#  '계룡백일주30%',
#  '계룡백일주40%',
#  '계룡산산삼주금수강산21%',
#  '계룡산산삼주금수강산40%',
#  '고구마아락',
#  '고도리레드와인스위트',
#  '고도리복숭아와인',
#  '고도리화이트와인드라이',
#  '고도리화이트와인스위트',
#  '고소리술',
#  '고은달백자',
#  '고은달오크',
#  '고창선운산땡큐복분자주',
#  '고창선운산땡큐블루베리주',
#  '고창선운산복분자주특1호',
#  '공주애오디와인',
#  '구기홍주14',
#  '구름을벗삼아',
#  '옛날막걸리古',
#  '귀감',
#  '그랑고또레드와인',
#  '그랑꼬또로제와인',
#  '그랑꼬또청수',
#  '그랑꼬또화이트와인',
#  '그랑꼬또M56',
#  '그랑꼬또M5610',
#  '그랑티그르CE2002',
#  '그랑티그르M1988',
#  '그랑티그르S1974',
#  '금산인삼주',
#  '금산인삼주수삼단본72023%',
#  '금산인삼주수삼단본72043%',
#  '금이산농원복숭아와인',
#  '금이산농원사과와인',
#  '금이산농원오가피와인',
#  '금정산성막걸리',
#  '기다림16',
#  '기다림25',
#  '기다림34',
#  '기다림맑은술',
#  '김천과하주16%',
# ...

# %%
for i, wiki_item in enumerate(naverwiki_list, start=0) :
    #print(wiki_item)
    for j, woori_item in enumerate(woorisool_list, start=0):
        #print(woori_item)
        if wiki_item in woori_item:
            print(i, wiki_item)
            print(j, woori_item)
            print('--------------------------------------------------')
# Out:
# 13 감사
# 132 감사블루 14도 375ml
# --------------------------------------------------
# 13 감사
# 335 감사블루 14도 375ml
# --------------------------------------------------
# 21 강쇠
# 283 술소리 지리산 강쇠 13도 375ml
# --------------------------------------------------
# 35 고소리술
# 112 [제주샘주] 제주샘 미니어쳐 3종세트 (고소리술+니모메+오메기술 3종)
# --------------------------------------------------
# 35 고소리술
# 114 [제주샘주] 고소리술 유리병 미니어쳐 29도 80ml
# --------------------------------------------------
# 35 고소리술
# 115 [제주샘주] 고소리술 도자기 미니어쳐 40도 65ml 소줏고리
# --------------------------------------------------
# 35 고소리술
# 276 [제주샘주] 제주도 소주 고소리술 40도 500ml 소줏고리 도자기
# --------------------------------------------------
# 35 고소리술
# 289 [제주샘] 소주 고소리술 40도 375ml
# --------------------------------------------------
# 35 고소리술
# 290 [제주샘주] 소주 고소리술 29도 375ml
# --------------------------------------------------
# 55 금산인삼주
# 119 김창수 명인 금산인삼주 미니어쳐 23도 120ml 일반증류주
# --------------------------------------------------
# 55 금산인삼주
# 130 금산인삼주 수삼 단본 43도 720
# ...
